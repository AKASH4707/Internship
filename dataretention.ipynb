# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
data1= pd.read_csv (r'C:\Users\Akash Manral\Downloads\Customer_retention_dataset_1\Customer_retention_dataset\customer_retention_datasetnew.csv')
data1
d=data1
d
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# ..                    ...                 ...
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# 265                             Ghaziabad
# ...

# %%
d.isnull().sum()
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %%
d.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
d.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
sns.countplot(x="1Gender of respondent",data=d)
print(d["1Gender of respondent"].value_counts())
# Out:
# Female    181
# Male       88
# Name: 1Gender of respondent, dtype: int64

# %%
sns.catplot(x="7 How do you access the internet while shopping on-line?",y="2 How old are you?", hue="1Gender of respondent",data=d,kind="bar")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-118-f081d9d5403d> in <module>
# ----> 1 sns.catplot(x="7 How do you access the internet while shopping on-line?",y="2 How old are you?", hue="1Gender of respondent",data=d,kind="bar")
#       2 plt.show()
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, seed, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3787     p = _CategoricalPlotter()
# ...

# %%
sns.countplot(x="2 How old are you? ",data=d)
print(d["2 How old are you? "].value_counts())
# Out:
# 31-40 years           81
# 21-30 years           79
# 41-50 yaers           70
# Less than 20 years    20
# 51 years and above    19
# Name: 2 How old are you? , dtype: int64

# %%
sns.countplot(x="3 Which city do you shop online from?",data=d)
print(d["3 Which city do you shop online from?"].value_counts())
# Out:
# Delhi            58
# Greater Noida    43
# Noida            40
# Bangalore        37
# Karnal           27
# Solan            18
# Ghaziabad        18
# Gurgaon          12
# Merrut            9
# Moradabad         5
# Bulandshahr       2
# Name: 3 Which city do you shop online from?, dtype: int64

# %%
sns.countplot(x="5 Since How Long You are Shopping Online ?",data=d)
print(d["5 Since How Long You are Shopping Online ?"].value_counts())
# Out:
# Above 4 years       98
# 2-3 years           65
# 3-4 years           47
# Less than 1 year    43
# 1-2 years           16
# Name: 5 Since How Long You are Shopping Online ?, dtype: int64

# %%
sns.countplot(x="6 How many times you have made an online purchase in the past 1 year?",data=d)
print(d["6 How many times you have made an online purchase in the past 1 year?"].value_counts())
# Out:
# Less than 10 times    114
# 31-40 times            63
# 41 times and above     47
# 11-20 times            29
# 21-30 times            10
# 42 times and above      6
# Name: 6 How many times you have made an online purchase in the past 1 year?, dtype: int64

# %%
sns.countplot(x="7 How do you access the internet while shopping on-line?",data=d)
print(d["7 How do you access the internet while shopping on-line?"].value_counts())
# Out:
# Mobile internet    142
# Wi-Fi               76
# Mobile Internet     47
# Dial-up              4
# Name: 7 How do you access the internet while shopping on-line?, dtype: int64

# %%
sns.countplot(x="8 Which device do you use to access the online shopping?",data=d)
print(d["8 Which device do you use to access the online shopping?"].value_counts())
# Out:
# Smartphone    141
# Laptop         86
# Desktop        30
# Tablet         12
# Name: 8 Which device do you use to access the online shopping?, dtype: int64

# %%
sns.countplot(x="10 What is the operating system (OS) of your device?\t\t\t\t                                          ",data=d)
print(d["10 What is the operating system (OS) of your device?\t\t\t\t                                          "].value_counts())
# Out:
# Window/windows Mobile    122
# Android                   85
# IOS/Mac                   62
# Name: 10 What is the operating system (OS) of your device?\t\t\t\t                                          , dtype: int64

# %% [markdown]
# # ENCODING DATAFRAME

# %%
from sklearn.preprocessing import OrdinalEncoder
enc=OrdinalEncoder()

# %%
for i in d.columns:
    if d[i].dtypes=="object":
        d[i]=enc.fit_transform(d[i].values.reshape(-1,1))

# %%
d
# Out:
#      1Gender of respondent  2 How old are you?   \
# 0                      1.0                  1.0
# 1                      0.0                  0.0
# 2                      0.0                  0.0
# 3                      1.0                  0.0
# 4                      0.0                  0.0
# ..                     ...                  ...
# 264                    0.0                  0.0
# 265                    0.0                  1.0
# 266                    0.0                  2.0
# 267                    0.0                  4.0
# 268                    0.0                  2.0
#
#      3 Which city do you shop online from?  \
# 0                                      2.0
# 1                                      2.0
# 2                                      4.0
# 3                                      6.0
# 4                                      0.0
# ..                                     ...
# 264                                   10.0
# ...

# %%
d.isnull().sum()
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %% [markdown]
# Above table has no missing data

# %% [markdown]
# # describe dataset

# %%
d.describe()
# Out:
#        1Gender of respondent  2 How old are you?   \
# count             269.000000           269.000000
# mean                0.327138             1.330855
# std                 0.470042             1.183774
# min                 0.000000             0.000000
# 25%                 0.000000             0.000000
# 50%                 0.000000             1.000000
# 75%                 1.000000             2.000000
# max                 1.000000             4.000000
#
#        3 Which city do you shop online from?  \
# count                             269.000000
# mean                                4.494424
# std                                 3.187687
# min                                 0.000000
# 25%                                 2.000000
# 50%                                 4.000000
# 75%                                 7.000000
# max                                10.000000
#
#        4 What is the Pin Code of where you shop online from?  \
# ...

# %% [markdown]
# in above table
# Key observations:
# 1- The mean is greater the median(50th percentile) in all columns,thus skewness is present in these columns
# 2- The outliers are not extreme

# %% [markdown]
# # heat map

# %%
sns.heatmap(d)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Data Set (d) has no null values

# %% [markdown]
# # corelation of columns with trgetcolumns

# %%
d.corr()
# Out:
#                                                     1Gender of respondent  \
# 1Gender of respondent                                            1.000000
# 2 How old are you?                                               0.046169
# 3 Which city do you shop online from?                            0.080912
# 4 What is the Pin Code of where you shop online...              -0.260365
# 5 Since How Long You are Shopping Online ?                      -0.057096
# ...                                                                   ...
# Longer delivery period                                           0.060838
# Change in website/Application design                            -0.164818
# Frequent disruption when moving from one page t...              -0.256638
# Website is as efficient as before                                0.055663
# Which of the Indian online retailer would you r...              -0.003372
#
#                                                     2 How old are you?   \
# ...

# %%
plt.figure(figsize=(10,6))
sns.heatmap(d.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# 1- lighter colors- high positive correlation
#
# 2- Darker colors- high negative correlation

# %%
d.skew()
# Out:
# 1Gender of respondent                                                   0.741028
# 2 How old are you?                                                      0.680987
# 3 Which city do you shop online from?                                   0.313729
# 4 What is the Pin Code of where you shop online from?                   1.748322
# 5 Since How Long You are Shopping Online ?                             -0.276968
#                                                                           ...
# Longer delivery period                                                 -0.147702
# Change in website/Application design                                    0.354163
# Frequent disruption when moving from one page to another               -0.100608
# Website is as efficient as before                                       0.662084
# Which of the Indian online retailer would you recommend to a friend?    0.583614
# Length: 71, dtype: float64

# %%
d.dtypes
# Out:
# 1Gender of respondent                                                   float64
# 2 How old are you?                                                      float64
# 3 Which city do you shop online from?                                   float64
# 4 What is the Pin Code of where you shop online from?                     int64
# 5 Since How Long You are Shopping Online ?                              float64
#                                                                          ...
# Longer delivery period                                                  float64
# Change in website/Application design                                    float64
# Frequent disruption when moving from one page to another                float64
# Website is as efficient as before                                       float64
# Which of the Indian online retailer would you recommend to a friend?    float64
# Length: 71, dtype: object

# %% [markdown]
# # checking outliers

# %%
d["5 Since How Long You are Shopping Online ?"].plot.box()
# Out:
# <AxesSubplot:>

# %%
d["3 Which city do you shop online from?"].plot.box()
# Out:
# <AxesSubplot:>

# %%
d["6 How many times you have made an online purchase in the past 1 year?"].plot.box()
# Out:
# <AxesSubplot:>

# %%
d.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
d["24 User friendly Interface of the website"].plot.box()
# Out:
# <AxesSubplot:>

# %%
d.plot(kind="box",subplots=True,layout=(12,6),figsize=(40,40))
# Out:
# 1Gender of respondent                                                      AxesSubplot(0.125,0.826831;0.110714x0.053169)
# 2 How old are you?                                                      AxesSubplot(0.257857,0.826831;0.110714x0.053169)
# 3 Which city do you shop online from?                                   AxesSubplot(0.390714,0.826831;0.110714x0.053169)
# 4 What is the Pin Code of where you shop online from?                   AxesSubplot(0.523571,0.826831;0.110714x0.053169)
# 5 Since How Long You are Shopping Online ?                              AxesSubplot(0.656429,0.826831;0.110714x0.053169)
#                                                                                               ...
# Longer delivery period                                                        AxesSubplot(0.125,0.125;0.110714x0.053169)
# Change in website/Application design                                       AxesSubplot(0.257857,0.125;0.110714x0.053169)
# ...

# %% [markdown]
# outliers shows that there are more higher values ,than the max value ,in a particular column

# %% [markdown]
# # To check the distribution of Skewness

# %%
d.plot(kind="kde",subplots=True,layout=(12,6),figsize=(50,50))
# Out:
# array([[<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
# ...

# %% [markdown]
# # Removing outliers

# %%
import numpy as np
import scipy
from scipy.stats import zscore
z=np.abs(zscore(d))
z
# Out:
# array([[1.43416114, 0.2800127 , 0.78397694, ..., 1.40519246, 0.98469733,
#         1.52727829],
#        [0.69727172, 1.12634321, 0.78397694, ..., 0.16163354, 0.52322768,
#         0.25533445],
#        [0.69727172, 1.12634321, 0.15539334, ..., 0.94504654, 0.98469733,
#         1.10329701],
#        ...,
#        [0.69727172, 0.56631782, 1.41256055, ..., 1.33675303, 0.98469733,
#         1.01660938],
#        [0.69727172, 2.25897885, 1.73035746, ..., 0.55334004, 1.32265095,
#         1.01660938],
#        [0.69727172, 0.56631782, 0.46968514, ..., 1.40519246, 0.98469733,
#         1.01660938]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  4,  16,  20,  30,  35,  49,  79,  88,  95, 112, 116, 133, 142,
#        159, 162, 196, 207, 234, 237, 262], dtype=int64), array([11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11,
#        11, 11, 11], dtype=int64))

# %%
d_new=d[(z<3).all(axis=1)]
d_new
# Out:
#      1Gender of respondent  2 How old are you?   \
# 0                      1.0                  1.0
# 1                      0.0                  0.0
# 2                      0.0                  0.0
# 3                      1.0                  0.0
# 5                      0.0                  1.0
# ..                     ...                  ...
# 264                    0.0                  0.0
# 265                    0.0                  1.0
# 266                    0.0                  2.0
# 267                    0.0                  4.0
# 268                    0.0                  2.0
#
#      3 Which city do you shop online from?  \
# 0                                      2.0
# 1                                      2.0
# 2                                      4.0
# 3                                      6.0
# 5                                      9.0
# ..                                     ...
# 264                                   10.0
# ...

# %%
d.shape
# Out:
# (269, 71)

# %%
d_new.shape
# Out:
# (249, 71)
