# %% [markdown]
# # database

# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
d= pd.read_csv(r'D:\program file\Micro Credit Project\Data file.csv')
d.head()
# Out:
#    Unnamed: 0  label       msisdn    aon  daily_decr30  daily_decr90  \
# 0           1      0  21408I70789  272.0   3055.050000   3065.150000
# 1           2      1  76462I70374  712.0  12122.000000  12124.750000
# 2           3      1  17943I70372  535.0   1398.000000   1398.000000
# 3           4      1  55773I70781  241.0     21.228000     21.228000
# 4           5      1  03813I82730  947.0    150.619333    150.619333
#
#    rental30  rental90  last_rech_date_ma  last_rech_date_da  ...  \
# 0    220.13    260.13                2.0                0.0  ...
# 1   3691.26   3691.26               20.0                0.0  ...
# 2    900.13    900.13                3.0                0.0  ...
# 3    159.42    159.42               41.0                0.0  ...
# 4   1098.90   1098.90                4.0                0.0  ...
#
#    maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 0              6.0                 0.0          2.0            12
# ...

# %%
d.shape
# Out:
# (209593, 37)

# %%
d.dropna()
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 0                1      0  21408I70789   272.0   3055.050000   3065.150000
# 1                2      1  76462I70374   712.0  12122.000000  12124.750000
# 2                3      1  17943I70372   535.0   1398.000000   1398.000000
# 3                4      1  55773I70781   241.0     21.228000     21.228000
# 4                5      1  03813I82730   947.0    150.619333    150.619333
# ...            ...    ...          ...     ...           ...           ...
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111667  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228333  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
# ...

# %%
d.shape
# Out:
# (209593, 37)

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 37 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Unnamed: 0            209593 non-null  int64
#  1   label                 209593 non-null  int64
#  2   msisdn                209593 non-null  object
#  3   aon                   209593 non-null  float64
#  4   daily_decr30          209593 non-null  float64
#  5   daily_decr90          209593 non-null  float64
#  6   rental30              209593 non-null  float64
#  7   rental90              209593 non-null  float64
#  8   last_rech_date_ma     209593 non-null  float64
#  9   last_rech_date_da     209593 non-null  float64
#  10  last_rech_amt_ma      209593 non-null  int64
#  11  cnt_ma_rech30         209593 non-null  int64
#  12  fr_ma_rech30          209593 non-null  float64
#  13  sumamnt_ma_rech30     209593 non-null  float64
# ...

# %%
d['pcircle'].value_counts()
# Out:
# UPW    209593
# Name: pcircle, dtype: int64

# %%
# we have data for both last 30 days and last 90 days, so we opt for last 90 days removed last 30 days column
d= d.drop(["Unnamed: 0",'msisdn','aon','daily_decr30','rental30','cnt_ma_rech30', 'fr_ma_rech30','sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30','fr_da_rech30',],axis=1)

# %%
d.head()
# Out:
#    label  daily_decr90  rental90  last_rech_date_ma  last_rech_date_da  \
# 0      0   3065.150000    260.13                2.0                0.0
# 1      1  12124.750000   3691.26               20.0                0.0
# 2      1   1398.000000    900.13                3.0                0.0
# 3      1     21.228000    159.42               41.0                0.0
# 4      1    150.619333   1098.90                4.0                0.0
#
#    last_rech_amt_ma  cnt_ma_rech90  fr_ma_rech90  sumamnt_ma_rech90  \
# 0              1539              2            21               3078
# 1              5787              1             0               5787
# 2              1539              1             0               1539
# 3               947              1             0                947
# 4              2309              8             2              23496
#
#    medianamnt_ma_rech90  ...  maxamnt_loans30  medianamnt_loans30  \
# ...

# %%
d.isnull().sum()
# Out:
# label                   0
# daily_decr90            0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# pcircle                 0
# pdate                   0
# dtype: int64

# %%
sns.heatmap(d.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # EDA

# %%
sns.countplot(d['label'])
d["label"].value_counts()
#label=Flag indicating whether the user paid back the credit amount within 5 days of issuing the loan{1:success, 0:failure}
# Out:
# 1    183431
# 0     26162
# Name: label, dtype: int64

# %%
d['label'].value_counts().plot(kind="pie",autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='label'>

# %% [markdown]
# observation-
#
# 87.52% of users paid back the credit amount within 5 days of issuing the loan
#
# 12.48% of users did not paid back the credit amount within 5 days of issuing the loan

# %%
d.last_rech_amt_ma.hist(bins=40)
#last_rech_amt_ma=Amount of last recharge of main account (in Indonesian Rupiah)
# Out:
# <AxesSubplot:>

# %% [markdown]
# max people have amount of last recharge of main account (in Indonesian Rupiah) between 0-1000 days approx
#
# min people have amount of last recharge of main account (in Indonesian Rupiah) beyond 10,000 days

# %%
d.hist(figsize=(30,30), layout=(10,3), sharex=False)
# Out:
# array([[<AxesSubplot:title={'center':'label'}>,
#         <AxesSubplot:title={'center':'daily_decr90'}>,
#         <AxesSubplot:title={'center':'rental90'}>],
#        [<AxesSubplot:title={'center':'last_rech_date_ma'}>,
#         <AxesSubplot:title={'center':'last_rech_date_da'}>,
#         <AxesSubplot:title={'center':'last_rech_amt_ma'}>],
#        [<AxesSubplot:title={'center':'cnt_ma_rech90'}>,
#         <AxesSubplot:title={'center':'fr_ma_rech90'}>,
#         <AxesSubplot:title={'center':'sumamnt_ma_rech90'}>],
#        [<AxesSubplot:title={'center':'medianamnt_ma_rech90'}>,
#         <AxesSubplot:title={'center':'medianmarechprebal90'}>,
#         <AxesSubplot:title={'center':'cnt_da_rech30'}>],
#        [<AxesSubplot:title={'center':'cnt_da_rech90'}>,
#         <AxesSubplot:title={'center':'fr_da_rech90'}>,
#         <AxesSubplot:title={'center':'cnt_loans30'}>],
#        [<AxesSubplot:title={'center':'amnt_loans30'}>,
# ...

# %%
d.columns
# Out:
# Index(['label', 'daily_decr90', 'rental90', 'last_rech_date_ma',
#        'last_rech_date_da', 'last_rech_amt_ma', 'cnt_ma_rech90',
#        'fr_ma_rech90', 'sumamnt_ma_rech90', 'medianamnt_ma_rech90',
#        'medianmarechprebal90', 'cnt_da_rech30', 'cnt_da_rech90',
#        'fr_da_rech90', 'cnt_loans30', 'amnt_loans30', 'maxamnt_loans30',
#        'medianamnt_loans30', 'cnt_loans90', 'amnt_loans90', 'maxamnt_loans90',
#        'medianamnt_loans90', 'payback30', 'payback90', 'pcircle', 'pdate'],
#       dtype='object')

# %%
sns.relplot(x='rental90',y='daily_decr90',hue='label',data=d)
#rental90= avg main account balance over last 90 days
#daily_decr90= daily amount spent from main account, averaged over last 90 days (in Indonesian Rupiah)

# %% [markdown]
# observation-
#
# 1-most of the people have their avg main account balance over last 90 days between 0-50,000 and their daily amount spent from main account, averaged over last 90 days (in Indonesian Rupiah) was also between 0-50000
#
# 2-very few peoplwe had their avg main account balance between 1lakh-2lakh and their spending was around 50000
#
# 3-a few cases were also there whose rantal 90 was around 60,000 and daily_decr90 was more than 3lakh

# %%
#sumamnt_ma_rech90=Total amount of recharge in main account over last 90 days (in Indonesian Rupiah)
d['sumamnt_ma_rech90'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# observation-
#
# most of the people have done  recharge in main account ,over last 90 days (in Indonesian Rupiah), of amount between (0.0-0.1)(le6)
# (0-100000 in Indonesian Rupiah).
#
# very few people have done recharge of amount between (100000-19000 Indonesian Rupiah )

# %%
#fr_ma_rech90=Frequency of main account recharged in last 90 days
sns.distplot(d['fr_ma_rech90'])
# Out:
# <AxesSubplot:xlabel='fr_ma_rech90', ylabel='Density'>

# %% [markdown]
# observation-
#
# highest Frequency of main account recharged in last 90 days - is between 0-5 days

# %%
#cnt_da_rech90=Number of times data account got recharged in last 90 days
d['cnt_da_rech90'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# observation-
#
# Number of times data account got recharged in last 90 days
#
# - 0-3 times mostly
# - beyond 3 times very less

# %%
#cnt_da_rech30=Number of times data account got recharged in last 30 days
d['cnt_da_rech30'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# observation-
#
# Every data account got recharged between 0-10000 times in last 30 days

# %%
#amnt_loans30-Total amount of loans taken by user in last 30 days
sns.distplot(d['amnt_loans30'])
# Out:
# <AxesSubplot:xlabel='amnt_loans30', ylabel='Density'>

# %% [markdown]
# observation-
#
# Total amount of loans taken by user in last 30 days-
# - max- between 0-10 times
# - min- beyond 100

# %%
#amnt_loans90-Total amount of loans taken by user in last 90 days
sns.distplot(d['amnt_loans90'])
# Out:
# <AxesSubplot:xlabel='amnt_loans90', ylabel='Density'>

# %% [markdown]
# observation-
#
# Total amount of loans taken by user in last 30 days-
#
# max- between 0-10 times
#
# min- beyond 100

# %%
#payback30=Average payback time in days over last 30 days
sns.relplot(x='amnt_loans30',y='payback30',hue='label', data=d)

# %%
observation-

most of the people low total amount of loan(0-50loans) were having average payback time of(0-50 days)

# %%
#payback30=Average payback time in days over last 30 days
d['payback30'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# observation-
#
# most of the people had avg payback time of 0-15days

# %%
#payback90=Average payback time in days over last 90 days
d['payback90'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# observation-
#
# Average payback time of most of the user is between 0-15 days,for the last 90 days

# %%
d.corr()
# Out:
#                          label  daily_decr90  rental90  last_rech_date_ma  \
# label                 1.000000      0.166150  0.075521           0.003728
# daily_decr90          0.166150      1.000000  0.471730           0.000908
# rental90              0.075521      0.471730  1.000000          -0.001688
# last_rech_date_ma     0.003728      0.000908 -0.001688           1.000000
# last_rech_date_da     0.001711     -0.001886  0.002794           0.001790
# last_rech_amt_ma      0.131804      0.264131  0.121416          -0.000147
# cnt_ma_rech90         0.236392      0.593069  0.345293           0.004263
# fr_ma_rech90          0.084385     -0.079530 -0.036524           0.001414
# sumamnt_ma_rech90     0.205793      0.768817  0.360601           0.002243
# medianamnt_ma_rech90  0.120855      0.250518  0.103151          -0.000726
# medianmarechprebal90  0.039300      0.036382  0.029547          -0.001086
# cnt_da_rech30         0.003827      0.000661 -0.000548          -0.003467
# ...

# %%
plt.figure(figsize=(18,18))
sns.heatmap(d.corr(),annot=True)
plt.show()

# %%
d=d.drop(['cnt_ma_rech90'],axis=1)

# %%
d.describe()
# Out:
#                label   daily_decr90       rental90  last_rech_date_ma  \
# count  209593.000000  209593.000000  209593.000000      209593.000000
# mean        0.875177    6082.515068    3483.406534        3755.847800
# std         0.330519   10918.812767    5770.461279       53905.892230
# min         0.000000     -93.012667  -24720.580000         -29.000000
# 25%         1.000000      42.692000     300.260000           1.000000
# 50%         1.000000    1500.000000    1334.000000           3.000000
# 75%         1.000000    7802.790000    4201.790000           7.000000
# max         1.000000  320630.000000  200148.110000      998650.377733
#
#        last_rech_date_da  last_rech_amt_ma   fr_ma_rech90  sumamnt_ma_rech90  \
# count      209593.000000     209593.000000  209593.000000      209593.000000
# mean         3712.202921       2064.452797       7.716780       12396.218352
# std         53374.833430       2370.786034      12.590251       16857.793882
# ...

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 25 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   label                 209593 non-null  int64
#  1   daily_decr90          209593 non-null  float64
#  2   rental90              209593 non-null  float64
#  3   last_rech_date_ma     209593 non-null  float64
#  4   last_rech_date_da     209593 non-null  float64
#  5   last_rech_amt_ma      209593 non-null  int64
#  6   fr_ma_rech90          209593 non-null  int64
#  7   sumamnt_ma_rech90     209593 non-null  int64
#  8   medianamnt_ma_rech90  209593 non-null  float64
#  9   medianmarechprebal90  209593 non-null  float64
#  10  cnt_da_rech30         209593 non-null  float64
#  11  cnt_da_rech90         209593 non-null  int64
#  12  fr_da_rech90          209593 non-null  int64
#  13  cnt_loans30           209593 non-null  int64
# ...

# %%
d=d.drop(['pcircle','pdate'],axis=1)

# %% [markdown]
# # outlier detection and removal

# %%
import scipy
from scipy.stats import zscore
z=np.abs(zscore(d))
z
# Out:
# array([[2.64789583, 0.27634619, 0.55858346, ..., 0.22959366, 2.9046997 ,
#         2.39409346],
#        [0.37765836, 0.5533797 , 0.03602034, ..., 0.22959366, 0.38562959,
#         0.41923266],
#        [0.37765836, 0.42903256, 0.44767352, ..., 0.22959366, 0.38562959,
#         0.41923266],
#        ...,
#        [0.37765836, 0.53319431, 0.93749981, ..., 0.22959366, 0.06820893,
#         0.04735622],
#        [0.37765836, 0.59455827, 0.4330386 , ..., 0.22959366, 0.38562959,
#         0.59938541],
#        [0.37765836, 0.14174607, 0.49427822, ..., 0.22959366, 0.38562959,
#         0.41923266]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([    21,     22,     22, ..., 209586, 209587, 209587], dtype=int64), array([ 6,  6, 22, ..., 18, 16, 20], dtype=int64))

# %%
d2=d[(z<3).all(axis=1)]
d2
# Out:
#         label  daily_decr90  rental90  last_rech_date_ma  last_rech_date_da  \
# 0           0   3065.150000    260.13                2.0                0.0
# 1           1  12124.750000   3691.26               20.0                0.0
# 2           1   1398.000000    900.13                3.0                0.0
# 3           1     21.228000    159.42               41.0                0.0
# 4           1    150.619333   1098.90                4.0                0.0
# ...       ...           ...       ...                ...                ...
# 209588      1    151.872333   1089.19                1.0                0.0
# 209589      1     36.936000   1728.36                4.0                0.0
# 209590      1  11904.350000   8893.20                3.0                0.0
# 209591      1  12574.370000    984.58                2.0               38.0
# 209592      1   4534.820000    631.20               13.0                0.0
#
# ...

# %%
d2.shape
# Out:
# (168705, 23)

# %%
x=d2.drop(['label'],axis=1)
x.head()
# Out:
#    daily_decr90  rental90  last_rech_date_ma  last_rech_date_da  \
# 0   3065.150000    260.13                2.0                0.0
# 1  12124.750000   3691.26               20.0                0.0
# 2   1398.000000    900.13                3.0                0.0
# 3     21.228000    159.42               41.0                0.0
# 4    150.619333   1098.90                4.0                0.0
#
#    last_rech_amt_ma  fr_ma_rech90  sumamnt_ma_rech90  medianamnt_ma_rech90  \
# 0              1539            21               3078                1539.0
# 1              5787             0               5787                5787.0
# 2              1539             0               1539                1539.0
# 3               947             0                947                 947.0
# 4              2309             2              23496                2888.0
#
#    medianmarechprebal90  cnt_da_rech30  ...  cnt_loans30  amnt_loans30  \
# ...

# %%
y=d2["label"]
y.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    1
# Name: label, dtype: int64

# %%
y.shape
# Out:
# (168705,)

# %% [markdown]
# # Testing on various models

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.33,random_state=42)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
lg=LogisticRegression()
dtc=DecisionTreeClassifier()
Rf=RandomForestClassifier()
Mn=MultinomialNB()

# %%
model=[lg,dtc,Rf]
for m in model:
    m.fit(x_train,y_train)
    m.score(x_train,y_train)
    predm=m.predict(x_test)
    print("Accuracy score of",m,"is")
    print(accuracy_score(y_test,predm))
    print(confusion_matrix(y_test,predm))
    print(classification_report(y_test,predm))
    print('\n')
# Out:
# Accuracy score of LogisticRegression() is
# 0.863183230650405
# [[  380  7370]
#  [  247 47676]]
#               precision    recall  f1-score   support
#
#            0       0.61      0.05      0.09      7750
#            1       0.87      0.99      0.93     47923
#
#     accuracy                           0.86     55673
#    macro avg       0.74      0.52      0.51     55673
# weighted avg       0.83      0.86      0.81     55673
#
#
#
# Accuracy score of DecisionTreeClassifier() is
# 0.8560163813697843
# [[ 3941  3809]
#  [ 4207 43716]]
#               precision    recall  f1-score   support
#
#            0       0.48      0.51      0.50      7750
#            1       0.92      0.91      0.92     47923
#
#     accuracy                           0.86     55673
#    macro avg       0.70      0.71      0.71     55673
# weighted avg       0.86      0.86      0.86     55673
#
#
#
# Accuracy score of RandomForestClassifier() is
# 0.9026458067644999
# [[ 3528  4222]
#  [ 1198 46725]]
# ...

# %% [markdown]
# best accuracy score is of RandomForest Classifier, we will use this model for prediction

# %%
pred=Rf.predict(x_test)

# %%
df= pd.DataFrame({"Actual label":y_test,"Predicted label":pred})
df
# Out:
#         Actual label  Predicted label
# 108892             1                1
# 97106              0                0
# 143679             0                0
# 53928              1                1
# 41632              1                1
# ...              ...              ...
# 51485              1                1
# 149610             1                1
# 99023              1                1
# 98329              1                1
# 141057             1                1
#
# [55673 rows x 2 columns]

# %%
plt.scatter(df['Actual label'],df['Predicted label'])

# %% [markdown]
# # AUC and ROC curve

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

# %%
y_pred_proba=Rf.predict_proba(x_test)[:,1]
y_pred_proba
# Out:
# array([0.94, 0.24, 0.13, ..., 0.93, 0.86, 0.99])

# %%
fpr,tpr,threshold=roc_curve(y_test,y_pred_proba)

# %%
fpr
# Out:
# array([0.        , 0.01574194, 0.01574194, 0.016     , 0.016     ,
#        0.016     , 0.016     , 0.016     , 0.016     , 0.016     ,
#        0.03083871, 0.03083871, 0.03096774, 0.03109677, 0.03109677,
#        0.03109677, 0.03109677, 0.03109677, 0.03109677, 0.03109677,
#        0.03109677, 0.04490323, 0.04490323, 0.04503226, 0.04503226,
#        0.06232258, 0.06232258, 0.06245161, 0.06245161, 0.06270968,
#        0.06270968, 0.06270968, 0.06283871, 0.06283871, 0.07729032,
#        0.07729032, 0.07729032, 0.07729032, 0.09341935, 0.09354839,
#        0.09354839, 0.09354839, 0.09367742, 0.09367742, 0.11045161,
#        0.11045161, 0.11058065, 0.11058065, 0.12541935, 0.12554839,
#        0.12554839, 0.12567742, 0.12567742, 0.14129032, 0.14180645,
#        0.15406452, 0.15406452, 0.16709677, 0.16709677, 0.16709677,
#        0.16709677, 0.17909677, 0.17909677, 0.17909677, 0.17922581,
#        0.17922581, 0.17922581, 0.19174194, 0.19174194, 0.19174194,
# ...

# %%
tpr
# Out:
# array([0.        , 0.1930597 , 0.19308057, 0.19308057, 0.1931223 ,
#        0.19320577, 0.19322663, 0.19326837, 0.19333097, 0.19335184,
#        0.32631513, 0.32637773, 0.3263986 , 0.3263986 , 0.32641946,
#        0.3264612 , 0.32648206, 0.3265238 , 0.32656553, 0.32660727,
#        0.32662813, 0.42545333, 0.42549507, 0.42551593, 0.42555767,
#        0.50132504, 0.50136678, 0.50140851, 0.50145024, 0.50145024,
#        0.50153371, 0.50155458, 0.50155458, 0.50157544, 0.56200572,
#        0.56206832, 0.56211005, 0.56213092, 0.61127225, 0.61127225,
#        0.61131398, 0.61139745, 0.61139745, 0.61141832, 0.65116958,
#        0.65119045, 0.65119045, 0.65123218, 0.68697703, 0.68697703,
#        0.68699789, 0.68699789, 0.68706049, 0.71700436, 0.71700436,
#        0.74191933, 0.74198193, 0.76362081, 0.76366254, 0.76372514,
#        0.76376688, 0.78392421, 0.78394508, 0.78398681, 0.78398681,
#        0.78402855, 0.78409115, 0.80116019, 0.80136886, 0.80143146,
# ...

# %%
threshold
# Out:
# array([2.00000000e+00, 1.00000000e+00, 9.98888889e-01, 9.95833333e-01,
#        9.92905522e-01, 9.92857143e-01, 9.91428571e-01, 9.91369994e-01,
#        9.91250000e-01, 9.91000000e-01, 9.90000000e-01, 9.87666667e-01,
#        9.87500000e-01, 9.84311688e-01, 9.83870968e-01, 9.83333333e-01,
#        9.82857143e-01, 9.82500000e-01, 9.81666667e-01, 9.81583333e-01,
#        9.80714286e-01, 9.80000000e-01, 9.76166667e-01, 9.76000000e-01,
#        9.72857143e-01, 9.70000000e-01, 9.69041759e-01, 9.68428571e-01,
#        9.67666667e-01, 9.66498969e-01, 9.65000000e-01, 9.63333333e-01,
#        9.62000000e-01, 9.62000000e-01, 9.60000000e-01, 9.53333333e-01,
#        9.53330525e-01, 9.50000000e-01, 9.50000000e-01, 9.48428571e-01,
#        9.47230480e-01, 9.43500000e-01, 9.42000000e-01, 9.41666667e-01,
#        9.40000000e-01, 9.36666667e-01, 9.35125743e-01, 9.33333333e-01,
#        9.30000000e-01, 9.27500000e-01, 9.27391304e-01, 9.27000000e-01,
# ...

# %%
plt.plot([0,1],[0,1],"k--")
plt.plot(fpr,tpr,label='RandomForestClassifier')
plt.xlabel('false positive rate')
plt.ylabel("true positive rate")
plt.title('Random forest classifier')
plt.show()
