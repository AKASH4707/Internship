# %% [markdown]
# # The following Analysis is done according to codesheet

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
data1= pd.read_csv (r'C:\Users\Akash Manral\Downloads\Customer_retention_dataset_1\Customer_retention_dataset\customer_retention_dataset.csv')
data1
d=data1
d
# Out:
#      1Gender of respondent  2 How old are you?   \
# 0                        0                    3
# 1                        1                    2
# 2                        1                    2
# 3                        0                    2
# 4                        1                    2
# ..                     ...                  ...
# 264                      1                    2
# 265                      1                    3
# 266                      1                    4
# 267                      1                    1
# 268                      1                    4
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# ...

# %%
d.isnull().sum()
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %%
d.head()
# Out:
#    1Gender of respondent  2 How old are you?   \
# 0                      0                    3
# 1                      1                    2
# 2                      1                    2
# 3                      0                    2
# 4                      1                    2
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#    5 Since How Long You are Shopping Online ?  \
# 0                                           5
# ...

# %%
d.dtypes
# Out:
# 1Gender of respondent                                                    int64
# 2 How old are you?                                                       int64
# 3 Which city do you shop online from?                                   object
# 4 What is the Pin Code of where you shop online from?                    int64
# 5 Since How Long You are Shopping Online ?                               int64
#                                                                          ...
# Longer delivery period                                                  object
# Change in website/Application design                                    object
# Frequent disruption when moving from one page to another                object
# Website is as efficient as before                                       object
# Which of the Indian online retailer would you recommend to a friend?    object
# Length: 71, dtype: object

# %%
d.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
d.isnull()
# Out:
#      1Gender of respondent  2 How old are you?   \
# 0                    False                False
# 1                    False                False
# 2                    False                False
# 3                    False                False
# 4                    False                False
# ..                     ...                  ...
# 264                  False                False
# 265                  False                False
# 266                  False                False
# 267                  False                False
# 268                  False                False
#
#      3 Which city do you shop online from?  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
# ..                                     ...
# 264                                  False
# ...

# %%
#to observe if any table has missing data or not
sns.heatmap(d.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# observation- No table has missing data

# %%
#Summary of Data
d.describe()
# Out:
#        1Gender of respondent  2 How old are you?   \
# count             269.000000           269.000000
# mean                0.669145             2.959108
# std                 0.471398             1.066012
# min                 0.000000             1.000000
# 25%                 0.000000             2.000000
# 50%                 1.000000             3.000000
# 75%                 1.000000             4.000000
# max                 1.000000             5.000000
#
#        4 What is the Pin Code of where you shop online from?  \
# count                                         269.000000
# mean                                       220465.747212
# std                                        140524.341051
# min                                        110008.000000
# 25%                                        122018.000000
# 50%                                        201303.000000
# 75%                                        201310.000000
# ...

# %%
#To find the correlation of columns
d.corr()
# Out:
#                                                     1Gender of respondent  \
# 1Gender of respondent                                            1.000000
# 2 How old are you?                                              -0.034449
# 4 What is the Pin Code of where you shop online...               0.260696
# 5 Since How Long You are Shopping Online ?                      -0.046005
# 6 How many times you have made an online purcha...               0.076121
# 7 How do you access the internet while shopping...              -0.200974
# 8 Which device do you use to access the online ...              -0.241847
# 9 What is the screen size of your mobile device...              -0.058760
# 10 What is the operating system (OS) of your de...              -0.038207
# 11 What browser do you run on your device to ac...              -0.116712
# 12 Which channel did you follow to arrive at yo...              -0.166694
# 13 After first visit, how do you reach the onli...               0.104118
# ...

# %%
plt.figure(figsize=(10,6))
sns.heatmap(d.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# observation-
#
# lighter colors- high positive correlation
#
# darker colors- high negative correlation

# %% [markdown]
# # Checking outliers

# %%
d.plot(kind="box",subplots=True,layout=(12,6),figsize=(40,40))
# Out:
# 1Gender of respondent                                                                                                                                                                                                     AxesSubplot(0.125,0.826831;0.110714x0.053169)
# 2 How old are you?                                                                                                                                                                                                     AxesSubplot(0.257857,0.826831;0.110714x0.053169)
# 4 What is the Pin Code of where you shop online from?                                                                                                                                                                  AxesSubplot(0.390714,0.826831;0.110714x0.053169)
# ...

# %% [markdown]
# observation- it shows the columns having values, exceeding the maximum values

# %% [markdown]
# # To check the distribution of Skewness

# %%
d.plot(kind="kde",subplots=True,layout=(12,6),figsize=(50,50))
# Out:
# array([[<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
# ...

# %% [markdown]
# # Data Analysis - Insights from the data

# %%
#Gender count : (1)- female, (0)- male
sns.countplot(x="1Gender of respondent",data=d)
print(d["1Gender of respondent"].value_counts())
# Out:
# 1    180
# 0     89
# Name: 1Gender of respondent, dtype: int64

# %% [markdown]
# observation
#
# 1- No. of female(1)- 180
#
# 2- NO. of male(0)- 89

# %%
#Age and Gender insight
sns.countplot(x="2 How old are you? ",hue="1Gender of respondent",data=d)
print(d["2 How old are you? "].value_counts())
# Out:
# 3    81
# 2    79
# 4    70
# 1    20
# 5    19
# Name: 2 How old are you? , dtype: int64

# %% [markdown]
# points- "2 How old are you? "
#
# 1- less than 1 year
#
# 2- 1-2 years
#
# 3- 2-3 years
#
# 4- 3-4 years
#
# 5- Above 4 years

# %%
#Cities and the people shopping insight
sns.countplot(x="3 Which city do you shop online from?",hue="1Gender of respondent",data=d)
print(d["3 Which city do you shop online from?"].value_counts())
# Out:
# Delhi            58
# Greater Noida    43
# Noida            40
# Bangalore        37
# Karnal           27
# Solan            18
# Ghaziabad        18
# Gurgaon          12
# Merrut            9
# Moradabad         5
# Bulandshahr       2
# Name: 3 Which city do you shop online from?, dtype: int64

# %%
#highest used pincode
sns.countplot(x="4 What is the Pin Code of where you shop online from?",hue="1Gender of respondent",data=d)
print(d["4 What is the Pin Code of where you shop online from?"].value_counts())
# Out:
# 201308    38
# 132001    19
# 201310    18
# 110044    16
# 173229     9
# 173212     9
# 250001     9
# 122018     8
# 560037     8
# 132036     8
# 560010     8
# 110011     7
# 110008     7
# 201306     7
# 110014     6
# 110018     6
# 201008     5
# 201009     5
# 201305     5
# 201312     5
# 244001     5
# 530068     5
# 201005     4
# 110009     4
# 110042     4
# 110039     4
# 110030     4
# 201304     4
# 122009     4
# 201303     4
# 560018     4
# 201001     4
# 560003     4
# 560002     4
# 560013     3
# 203001     2
# 203207     1
# 560001     1
# 203202     1
# Name: 4 What is the Pin Code of where you shop online from?, dtype: int64

# %%
sns.countplot(x="6 How many times you have made an online purchase in the past 1 year?",hue="1Gender of respondent",data=d)
print(d["6 How many times you have made an online purchase in the past 1 year?"].value_counts())
# Out:
# 1    114
# 4     63
# 5     53
# 2     29
# 3     10
# Name: 6 How many times you have made an online purchase in the past 1 year?, dtype: int64

# %% [markdown]
# points-6 How many times you have made an online purchase in the past 1 year?
#
# 1-less than 10 times
#
# 2-11-20 times
#
# 3-21-30 times
#
# 4-31-40 times
#
# 5-40 times and above

# %%
#Gender and ways of accessing internet while shopping online
sns.countplot(x="7 How do you access the internet while shopping on-line?",hue="1Gender of respondent",data=d)
print(d["7 How do you access the internet while shopping on-line?"].value_counts())
# Out:
# 3    118
# 2     76
# 5     71
# 4      4
# Name: 7 How do you access the internet while shopping on-line?, dtype: int64

# %% [markdown]
# points- 7 How do you access the internet while shopping on-line?
#
# 1-
#
# 2-wifi
#
# 3-mobile Internet
#
# 4-dial up
#
# 5-mobile internet

# %%
sns.countplot(x="8 Which device do you use to access the online shopping?",hue="1Gender of respondent",data=d)
print(d["8 Which device do you use to access the online shopping?"].value_counts())
# Out:
# 1    141
# 2     86
# 3     30
# 4     12
# Name: 8 Which device do you use to access the online shopping?, dtype: int64

# %% [markdown]
# points-8 Which device do you use to access the online shopping?
#
# 1-Smartphone
#
# 2-Laptop
#
# 3-Desktop
#
# 4-Tablet

# %%
# operating system insight
sns.countplot(x="10 What is the operating system (OS) of your device?\t\t\t\t                                          ",hue="1Gender of respondent",data=d)
print(d["10 What is the operating system (OS) of your device?\t\t\t\t                                          "].value_counts())
# Out:
# 1    122
# 2     85
# 3     62
# Name: 10 What is the operating system (OS) of your device?\t\t\t\t                                          , dtype: int64

# %% [markdown]
# points- 10 What is the operating system (OS) of your device?
#
# 1- Window/windows Mobile
#
# 2- Android
#
# 3- IOS/Mac

# %%
sns.catplot(x="3 Which city do you shop online from?",y="8 Which device do you use to access the online shopping?", hue="1Gender of respondent",data=d,kind="bar")
plt.show()

# %%
##Insights of which o/s is being used in which city ,and by which gender
sns.catplot(x="3 Which city do you shop online from?",y="10 What is the operating system (OS) of your device?\t\t\t\t                                          ", hue="1Gender of respondent",data=d,kind="bar")
plt.show()

# %% [markdown]
# points- 10 What is the operating system (OS) of your device?
#
# 1- Window/windows Mobile
#
# 2- Android
#
# 3- IOS/Mac

# %% [markdown]
# # Insights on agreement of people

# %% [markdown]
# # points-
#
# 1- Strongly disagree
#
# 2- Dis-agree
#
# 3- Indifferent
#
# 4- Agree
#
# 5- Strongly agree

# %%
#21 All relevant information on listed products must be stated clearly insights-
sns.countplot(x="21 All relevant information on listed products must be stated clearly",hue="1Gender of respondent",data=d)
print(d["21 All relevant information on listed products must be stated clearly"].value_counts())
# Out:
# 4    132
# 5    107
# 1     18
# 2     12
# Name: 21 All relevant information on listed products must be stated clearly, dtype: int64

# %%
#22 Ease of navigation in website-
sns.countplot(x="22 Ease of navigation in website",hue="1Gender of respondent",data=d)
print(d["22 Ease of navigation in website"].value_counts())
# Out:
# 5    141
# 4    105
# 1     18
# 2      5
# Name: 22 Ease of navigation in website, dtype: int64

# %%
sns.countplot(x="25 Convenient Payment methods",hue="1Gender of respondent",data=d)
print(d["25 Convenient Payment methods"].value_counts())
# Out:
# 5    159
# 4     80
# 2     30
# Name: 25 Convenient Payment methods, dtype: int64

# %%
sns.countplot(x="23 Loading and processing speed",hue="1Gender of respondent",data=d)
print(d["23 Loading and processing speed"].value_counts())
# Out:
# 5    115
# 4    112
# 2     18
# 1     12
# 3     12
# Name: 23 Loading and processing speed, dtype: int64

# %%
#30 Online shopping gives monetary benefit and discounts insights-
sns.countplot(x="30 Online shopping gives monetary benefit and discounts",hue="1Gender of respondent",data=d)
print(d["30 Online shopping gives monetary benefit and discounts"].value_counts())
# Out:
# 5    105
# 4     85
# 3     50
# 1     18
# 2     11
# Name: 30 Online shopping gives monetary benefit and discounts, dtype: int64

# %%
#32 Shopping online is convenient and flexible insights-
sns.countplot(x="32 Shopping online is convenient and flexible",hue="1Gender of respondent",data=d)
print(d["32 Shopping online is convenient and flexible"].value_counts())
# Out:
# 5    146
# 4     78
# 3     33
# 2     12
# Name: 32 Shopping online is convenient and flexible, dtype: int64

# %%
#33 Return and replacement policy of the e-tailer is important for purchase decision insights-
sns.countplot(x="33 Return and replacement policy of the e-tailer is important for purchase decision",hue="1Gender of respondent",data=d)
print(d["33 Return and replacement policy of the e-tailer is important for purchase decision"].value_counts())
# Out:
# 5    198
# 4     51
# 2     20
# Name: 33 Return and replacement policy of the e-tailer is important for purchase decision, dtype: int64

# %%
#35 Displaying quality Information on the website improves satisfaction of customers insights-
sns.countplot(x="35 Displaying quality Information on the website improves satisfaction of customers",hue="1Gender of respondent",data=d)
print(d["35 Displaying quality Information on the website improves satisfaction of customers"].value_counts())
# Out:
# 5    133
# 4     80
# 3     56
# Name: 35 Displaying quality Information on the website improves satisfaction of customers, dtype: int64

# %%
#37 Net Benefit derived from shopping online can lead to users satisfaction insights-
sns.countplot(x="37 Net Benefit derived from shopping online can lead to users satisfaction",hue="1Gender of respondent",data=d)
print(d["37 Net Benefit derived from shopping online can lead to users satisfaction"].value_counts())
# Out:
# 5    164
# 4     54
# 3     40
# 2     11
# Name: 37 Net Benefit derived from shopping online can lead to users satisfaction, dtype: int64

# %%
#38 User satisfaction cannot exist without trust insights-
sns.countplot(x="38 User satisfaction cannot exist without trust",hue="1Gender of respondent",data=d)
print(d["38 User satisfaction cannot exist without trust"].value_counts())
# Out:
# 5    122
# 4    117
# 1     18
# 2      7
# 3      5
# Name: 38 User satisfaction cannot exist without trust, dtype: int64

# %%
#40 Provision of complete and relevant product information insights-
sns.countplot(x="40 Provision of complete and relevant product information",hue="1Gender of respondent",data=d)
print(d["40 Provision of complete and relevant product information"].value_counts())
# Out:
# 5    135
# 4     98
# 3     31
# 2      5
# Name: 40 Provision of complete and relevant product information, dtype: int64

# %%
#45 You feel gratification shopping on your favorite e-tailer insights-
sns.countplot(x="45 You feel gratification shopping on your favorite e-tailer",hue="1Gender of respondent",data=d)
print(d["45 You feel gratification shopping on your favorite e-tailer"].value_counts())
# Out:
# 3    101
# 5     65
# 4     63
# 2     22
# 1     18
# Name: 45 You feel gratification shopping on your favorite e-tailer, dtype: int64

# %% [markdown]
# # favourite websites of people

# %%
#Easy to use website or application insights-
sns.countplot(x="Easy to use website or application",hue="1Gender of respondent",data=d)
print(d["Easy to use website or application"].value_counts())
# Out:
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    64
# Amazon.in, Flipkart.com                                         44
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               44
# Amazon.in                                                       29
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                22
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in, Flipkart.com, Myntra.com                             19
# Paytm.com                                                       12
# Flipkart.com                                                     8
# Amazon.in, Paytm.com                                             7
# Name: Easy to use website or application, dtype: int64

# %%
#Fast loading website speed of website and application insights-
sns.countplot(x="Fast loading website speed of website and application",hue="1Gender of respondent",data=d)
print(d["Fast loading website speed of website and application"].value_counts())
# Out:
# Amazon.in                                                       51
# Amazon.in, Paytm.com                                            44
# Amazon.in, Flipkart.com                                         30
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    30
# Amazon.in, Flipkart.com, Myntra.com                             30
# Amazon.in, Flipkart.com, Paytm.com                              25
# Amazon.in, Flipkart.com, Snapdeal.com                           25
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Snapdeal.com                                                    12
# Flipkart.com                                                     8
# Name: Fast loading website speed of website and application, dtype: int64

# %%
#Reliability of the website or application insights-
sns.countplot(x="Reliability of the website or application",hue="1Gender of respondent",data=d)
print(d["Reliability of the website or application"].value_counts())
# Out:
# Amazon.in                                            61
# Amazon.in, Flipkart.com                              50
# Amazon.in, Flipkart.com, Paytm.com                   36
# Amazon.in, Paytm.com, Myntra.com                     35
# Amazon.in, Flipkart.com, Snapdeal.com                18
# Myntra.com                                           15
# Flipkart.com                                         15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com    14
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com     13
# Paytm.com                                            12
# Name: Reliability of the website or application, dtype: int64

# %%
#Speedy order delivery  insights-
sns.countplot(x="Speedy order delivery ",hue="1Gender of respondent",data=d)
print(d["Speedy order delivery "].value_counts())
# Out:
# Amazon.in                                 107
# Amazon.in, Flipkart.com                    82
# Amazon.in, Flipkart.com, Snapdeal.com      36
# Amazon.in, Flipkart.com, Myntra.com        15
# Flipkart.com                               15
# Flipkart.com, Myntra.com, Snapdeal.com     14
# Name: Speedy order delivery , dtype: int64

# %%
#which site gives longest time in displaying graphics and photos insight
sns.countplot(x="Longer time in displaying graphics and photos (promotion, sales period)",hue="1Gender of respondent",data=d)
print(d["Longer time in displaying graphics and photos (promotion, sales period)"].value_counts())
# Out:
# Amazon.in, Flipkart.com                60
# Amazon.in                              39
# Myntra.com                             35
# Snapdeal.com                           34
# Myntra.com, Snapdeal.com               25
# Flipkart.com, Snapdeal.com             19
# Paytm.com                              15
# Flipkart.com                           15
# Amazon.in, Myntra.com, Snapdeal.com    14
# Amazon.in, Paytm.com                   13
# Name: Longer time in displaying graphics and photos (promotion, sales period), dtype: int64

# %%
sns.countplot(x="Limited mode of payment on most products (promotion, sales period)",data=d)
print(d["Limited mode of payment on most products (promotion, sales period)"].value_counts())
# Out:
# Snapdeal.com                87
# Amazon.in                   62
# Flipkart.com                31
# Amazon.in, Flipkart.com     29
# Paytm.com                   25
# Paytm.com, Snapdeal.com     15
# Amazon.in, Paytm.com        13
# Myntra.com, Snapdeal.com     7
# Name: Limited mode of payment on most products (promotion, sales period), dtype: int64

# %%
# Website is as efficient as before insight-
sns.countplot(x="Website is as efficient as before",hue="1Gender of respondent",data=d)
print(d["Website is as efficient as before"].value_counts())
# Out:
# Amazon.in                             94
# Flipkart.com                          47
# Amazon.in, Flipkart.com               45
# Amazon.in, Flipkart.com, Paytm.com    25
# Amazon.in, Paytm.com                  18
# Paytm.com                             15
# Myntra.com, Snapdeal.com              14
# Snapdeal.com                          11
# Name: Website is as efficient as before, dtype: int64

# %%
# Longer delivery period insight-
sns.countplot(x="Longer delivery period",hue="1Gender of respondent",data=d)
print(d["Longer delivery period"].value_counts())
# Out:
# Paytm.com                  72
# Snapdeal.com               64
# Flipkart.com               44
# Amazon.in                  37
# Paytm.com, Snapdeal.com    26
# Myntra.com                 26
# Name: Longer delivery period, dtype: int64

# %%
# Reliability of the website or application insight-
sns.countplot(x="Reliability of the website or application",hue="1Gender of respondent",data=d)
print(d["Reliability of the website or application"].value_counts())
# Out:
# Amazon.in                                            61
# Amazon.in, Flipkart.com                              50
# Amazon.in, Flipkart.com, Paytm.com                   36
# Amazon.in, Paytm.com, Myntra.com                     35
# Amazon.in, Flipkart.com, Snapdeal.com                18
# Myntra.com                                           15
# Flipkart.com                                         15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com    14
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com     13
# Paytm.com                                            12
# Name: Reliability of the website or application, dtype: int64

# %%
# which site did they prefer to recommend to a friend insight-
sns.countplot(x="Which of the Indian online retailer would you recommend to a friend?",hue="1Gender of respondent",data=d)
print(d["Which of the Indian online retailer would you recommend to a friend?"].value_counts())
# Out:
# Amazon.in                                            79
# Amazon.in, Flipkart.com                              62
# Flipkart.com                                         39
# Amazon.in, Myntra.com                                30
# Amazon.in, Paytm.com, Myntra.com                     20
# Amazon.in, Flipkart.com, Myntra.com                  15
# Amazon.in, Paytm.com                                 13
# Flipkart.com, Paytm.com, Myntra.com, snapdeal.com    11
# Name: Which of the Indian online retailer would you recommend to a friend?, dtype: int64
